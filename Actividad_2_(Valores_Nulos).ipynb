# %% [markdown]
# <a href="https://colab.research.google.com/github/roymata123/VALORESNULOSRM/blob/main/Actividad_2_(Valores_Nulos).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .csv sin indice
data = pd.read_csv('Ventas_totales.csv')

# %%
#Eliminar primera fila o filas innecesarias
data1= pd.read_csv('Ventas_totales.csv')
data1
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# electronicos_articulos_hogar           0
# ...

# %% [markdown]
# **Métodos de Sustitución de Valores Nulos**

# %%
#Tercer método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en  concreto
data1["salon_ventas"]= data1["salon_ventas"].fillna(10)
data1
data1["tarjetas_debito"]= data1["tarjetas_debito"].fillna(10)
data1
data1["otros_medios"]= data1["otros_medios"].fillna(10)
data1
data1["tarjetas_credito"]= data1["tarjetas_credito"].fillna(10)
data1
data1["subtotal_ventas_alimentos_bebidas"]= data1["subtotal_ventas_alimentos_bebidas"].fillna(10)
data1
data1["bebidas"]= data1["bebidas"].fillna(10)
data1
data1["almacen"]= data1["almacen"].fillna(10)
data1
data1["panaderia"]= data1["panaderia"].fillna(10)
data1
data1["lacteos"]= data1["lacteos"].fillna(10)
data1
data1["carnes"]= data1["carnes"].fillna(10)
data1
data1["verduleria_fruteria"]= data1["verduleria_fruteria"].fillna(10)
data1
data1["alimentos_preparados_rotiseria"]= data1["alimentos_preparados_rotiseria"].fillna(10)
data1
data1["indumentaria_calzado_textiles_hogar"]= data1["indumentaria_calzado_textiles_hogar"].fillna(10)
data1
data1["electronicos_articulos_hogar"]= data1["electronicos_articulos_hogar"].fillna(10)
data1
data1["otros"]= data1["otros"].fillna(10)
data1
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...
